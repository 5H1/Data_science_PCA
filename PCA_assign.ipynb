# %%
#Task 1: Exploratory Data Analysis (EDA):
#1.Load the dataset and perform basic data exploration.
#2.Examine the distribution of features using histograms, box plots, or density plots.
#3.Investigate correlations between features to understand relationships within the data.

# %%
##STEP 1:IMPORTING DATA FILE
#==================================================================
import numpy as np
import pandas as pd
df = pd.read_csv("wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
#HISTOGRAMS BOXPLOTS AND DENSITY PLOTS
#STEP 2

# %%
#HISTOGRAMS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
#	step 2 a Construct the histogram for all X variables
plt.hist(df["Alcohol"])
plt.show()
##Malic
plt.hist(df["Malic"])
plt.show()
##Ash
plt.hist(df["Ash"])
plt.show()

# %%
##Alcalinity
plt.hist(df["Alcalinity"])
plt.show()
##Magnesium
plt.hist(df["Magnesium"])
plt.show()
##Phenols
plt.hist(df["Phenols"])
plt.show()

# %%
##Flavanoids
plt.hist(df["Flavanoids"])
plt.show()
##Nonflavanoids
plt.hist(df["Nonflavanoids"])
plt.show()
##Proanthocyanins
plt.hist(df["Proanthocyanins"])
plt.show()

# %%
##Color
plt.hist(df["Color"])
plt.show()
##Hue
plt.hist(df["Hue"])
plt.show()
##Dilution
plt.hist(df["Dilution"])
plt.show()

# %%
##Proline
plt.hist(df["Proline"])
plt.show()

# %%
# STEP 2 B BOXPLOTS

# %%
##STEP 2 BOXPLOTS
#step 2 a. performing Box plot on Alcohol column and observing outliers and inter quartile ranges
df.boxplot(column='Alcohol',vert=False)

import numpy as np
q1 = np.percentile(df["Alcohol"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Alcohol"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Alcohol"][df["Alcohol"] > UW]))

##we can observe that there are 0 outliers
# Out:
# 25th percentile 12.362499999999999
# 75th percentile 13.6775
# Inter quartile range: 1.3150000000000013
# Upper whisker length: 15.650000000000002
# number of outliers greater than upper whisker: 0

# %%
##STEP 2 BOXPLOTS
#step 2 b. performing Box plot on Malic column and observing outliers and inter quartile ranges
df.boxplot(column='Malic',vert=False)

import numpy as np
q1 = np.percentile(df["Malic"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Malic"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Malic"][df["Malic"] > UW]))

##we can observe that there are 3 outliers
# Out:
# 25th percentile 1.6025
# 75th percentile 3.0825
# Inter quartile range: 1.48
# Upper whisker length: 5.3025
# number of outliers greater than upper whisker: 3

# %%
##STEP 2 BOXPLOTS
#step 2 c. performing Box plot on Ash column and observing outliers and inter quartile ranges
df.boxplot(column='Ash',vert=False)

import numpy as np
q1 = np.percentile(df["Ash"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Ash"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Ash"][df["Ash"] > UW]))
# Out:
# 25th percentile 2.21
# 75th percentile 2.5575
# Inter quartile range: 0.34750000000000014
# Upper whisker length: 3.0787500000000003
# number of outliers greater than upper whisker: 2

# %%
##STEP 2 BOXPLOTS
#step 2 d. performing Box plot on Alcalinity column and observing outliers and inter quartile ranges
df.boxplot(column='Alcalinity',vert=False)

import numpy as np
q1 = np.percentile(df["Alcalinity"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Alcalinity"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Alcalinity"][df["Alcalinity"] > UW]))
# Out:
# 25th percentile 17.2
# 75th percentile 21.5
# Inter quartile range: 4.300000000000001
# Upper whisker length: 27.950000000000003
# number of outliers greater than upper whisker: 3

# %%
##STEP 2 BOXPLOTS
#step 2 e. performing Box plot on Magnesium column and observing outliers and inter quartile ranges
df.boxplot(column='Magnesium',vert=False)

import numpy as np
q1 = np.percentile(df["Magnesium"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Magnesium"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Magnesium"][df["Magnesium"] > UW]))
# Out:
# 25th percentile 88.0
# 75th percentile 107.0
# Inter quartile range: 19.0
# Upper whisker length: 135.5
# number of outliers greater than upper whisker: 4

# %%
##STEP 2 BOXPLOTS
#step 2 f. performing Box plot on Phenols column and observing outliers and inter quartile ranges
df.boxplot(column='Phenols',vert=False)

import numpy as np
q1 = np.percentile(df["Phenols"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Phenols"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Phenols"][df["Phenols"] > UW]))
# Out:
# 25th percentile 1.7425
# 75th percentile 2.8
# Inter quartile range: 1.0574999999999999
# Upper whisker length: 4.3862499999999995
# number of outliers greater than upper whisker: 0

# %%
##STEP 2 BOXPLOTS
#step 2 g performing Box plot on Flavanoids column and observing outliers and inter quartile ranges
df.boxplot(column='Flavanoids',vert=False)

import numpy as np
q1 = np.percentile(df["Flavanoids"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Flavanoids"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Flavanoids"][df["Flavanoids"] > UW]))
# Out:
# 25th percentile 1.205
# 75th percentile 2.875
# Inter quartile range: 1.67
# Upper whisker length: 5.38
# number of outliers greater than upper whisker: 0

# %%
##STEP 2 BOXPLOTS
#step 2 h performing Box plot on Nonlavanoids column and observing outliers and inter quartile ranges
df.boxplot(column='Nonflavanoids',vert=False)

import numpy as np
q1 = np.percentile(df["Nonflavanoids"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Nonflavanoids"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Nonflavanoids"][df["Nonflavanoids"] > UW]))
# Out:
# 25th percentile 0.27
# 75th percentile 0.4375
# Inter quartile range: 0.16749999999999998
# Upper whisker length: 0.68875
# number of outliers greater than upper whisker: 0

# %%
##STEP 2 BOXPLOTS
#step 2 i performing Box plot on Proanthocyanins column and observing outliers and inter quartile ranges
df.boxplot(column='Proanthocyanins',vert=False)

import numpy as np
q1 = np.percentile(df["Proanthocyanins"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Proanthocyanins"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Proanthocyanins"][df["Proanthocyanins"] > UW]))
# Out:
# 25th percentile 1.25
# 75th percentile 1.95
# Inter quartile range: 0.7
# Upper whisker length: 3.0
# number of outliers greater than upper whisker: 2

# %%
##STEP 2 BOXPLOTS
#step 2 j performing Box plot on Cpolor column and observing outliers and inter quartile ranges
df.boxplot(column='Color',vert=False)

import numpy as np
q1 = np.percentile(df["Color"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Color"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Color"][df["Color"] > UW]))
# Out:
# 25th percentile 3.2199999999999998
# 75th percentile 6.2
# Inter quartile range: 2.9800000000000004
# Upper whisker length: 10.670000000000002
# number of outliers greater than upper whisker: 4

# %%
##STEP 2 BOXPLOTS
#step 2 k performing Box plot on Hue column and observing outliers and inter quartile ranges
df.boxplot(column='Hue',vert=False)

import numpy as np
q1 = np.percentile(df["Hue"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Hue"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Hue"][df["Hue"] > UW]))
# Out:
# 25th percentile 0.7825
# 75th percentile 1.12
# Inter quartile range: 0.33750000000000013
# Upper whisker length: 1.6262500000000002
# number of outliers greater than upper whisker: 1

# %%
##STEP 2 BOXPLOTS
#step 2 l performing Box plot on Dilution column and observing outliers and inter quartile ranges
df.boxplot(column='Dilution',vert=False)

import numpy as np
q1 = np.percentile(df["Dilution"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Dilution"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Dilution"][df["Dilution"] > UW]))
# Out:
# 25th percentile 1.9375
# 75th percentile 3.17
# Inter quartile range: 1.2325
# Upper whisker length: 5.01875
# number of outliers greater than upper whisker: 0

# %%
##STEP 2 BOXPLOTS
#step 2 m performing Box plot on Proline column and observing outliers and inter quartile ranges
df.boxplot(column='Proline',vert=False)

import numpy as np
q1 = np.percentile(df["Proline"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Proline"],75)
print("75th percentile",q3)

iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)

print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Proline"][df["Proline"] > UW]))
# Out:
# 25th percentile 500.5
# 75th percentile 985.0
# Inter quartile range: 484.5
# Upper whisker length: 1711.75
# number of outliers greater than upper whisker: 0

# %%
##DENSITY PLOTS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Alcohol'], shade=True)
plt.title('Density Plot of Alcohol')
plt.xlabel('Alcohol')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\1649471333.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Alcohol'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Malic'], shade=True)
plt.title('Density Plot of Malic')
plt.xlabel('Malic')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\1786020592.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Malic'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Alcalinity'], shade=True)
plt.title('Density Plot of Alcalinity')
plt.xlabel('Alcanlinity')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\1521057304.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Alcalinity'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Ash'], shade=True)
plt.title('Density Plot of Ash')
plt.xlabel('Ash')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\949440092.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Ash'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Magnesium'], shade=True)
plt.title('Density Plot of Magnesium')
plt.xlabel('Magnesium')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\2281984606.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Magnesium'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Phenols'], shade=True)
plt.title('Density Plot of Phenols')
plt.xlabel('Phenols')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\1027311473.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Phenols'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Flavanoids'], shade=True)
plt.title('Density Plot of Flavanoids')
plt.xlabel('Flavanoids')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\2560337136.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Flavanoids'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Nonflavanoids'], shade=True)
plt.title('Density Plot of Nonflavanoids')
plt.xlabel('NonFlavanoids')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\219093560.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Nonflavanoids'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Proanthocyanins'], shade=True)
plt.title('Density Plot of Proanthocyanins')
plt.xlabel('Proanthocyanins')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\4082467394.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Proanthocyanins'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Color'], shade=True)
plt.title('Density Plot of Color')
plt.xlabel('Color')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\1899148279.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Color'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Hue'], shade=True)
plt.title('Density Plot of Hue')
plt.xlabel('Hue')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\4231306548.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Hue'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Dilution'], shade=True)
plt.title('Density Plot of DIlution')
plt.xlabel('Dilution')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\2371143031.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Dilution'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset 
# Identify continuous features 

wdata=pd.read_csv("wine.csv")
# Plotting density plot
sns.kdeplot(wdata['Proline'], shade=True)
plt.title('Density Plot of Proline')
plt.xlabel('Proline')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_4248\4118024096.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wdata['Proline'], shade=True)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#3.Investigate correlations between features to understand relationships within the data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv("wine.csv")

# Compute the correlation matrix
correlation_matrix = data.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Add title and labels for better understanding
plt.title('Correlation Heatmap of Wine Dataset')
plt.show()

# %%
#Task 2: Dimensionality Reduction with PCA:
#1.	Standardize the features to ensure they have a mean of 0 and a standard deviation of Implement PCA to reduce the dimensionality of the dataset.
#2.	Determine the optimal number of principal components using techniques like scree plot or cumulative explained variance.
#3.	Transform the original dataset into the principal components.

# %%
#Declaring X and Y variables
Y = df["Type"]
X = df.iloc[:,1:]

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)
SS_X = pd.DataFrame(SS_X)
SS_X.columns = list(X)

SS_X.head()
# Out:
#     Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  Flavanoids  \
# 0  1.518613 -0.562250  0.232053   -1.169593   1.913905  0.808997    1.034819
# 1  0.246290 -0.499413 -0.827996   -2.490847   0.018145  0.568648    0.733629
# 2  0.196879  0.021231  1.109334   -0.268738   0.088358  0.808997    1.215533
# 3  1.691550 -0.346811  0.487926   -0.809251   0.930918  2.491446    1.466525
# 4  0.295700  0.227694  1.840403    0.451946   1.281985  0.808997    0.663351
#
#    Nonflavanoids  Proanthocyanins     Color       Hue  Dilution   Proline
# 0      -0.659563         1.224884  0.251717  0.362177  1.847920  1.013009
# 1      -0.820719        -0.544721 -0.293321  0.406051  1.113449  0.965242
# 2      -0.498407         2.135968  0.269020  0.318304  0.788587  1.395148
# 3      -0.981875         1.032155  1.186068 -0.427544  1.184071  2.334574
# 4       0.226796         0.401404 -0.319276  0.362177  0.449601 -0.037874

# %%
#Task 2: Dimensionality Reduction with PCA:
##1.Standardize the features to ensure they have a mean of 0 and a standard deviation of Implement PCA to reduce the dimensionality of the dataset.
#2.	Determine the optimal number of principal components using techniques like scree plot or cumulative explained variance.
#3.	Transform the original dataset into the principal components.

# %%
#observing the variances for the columns

# %%
from sklearn.decomposition import PCA
pca = PCA()

SS_X.head()

pc = pca.fit_transform(SS_X)
pc = pd.DataFrame(pc)
pc.head()

pc.iloc[:,0].var()
pc.iloc[:,1].var()
pc.iloc[:,2].var()

for i in range(0,13):
    print("variance: ",pc.iloc[:,i].var())

pd.DataFrame(pca.explained_variance_ratio_)

sum(pca.explained_variance_ratio_*100)
# Out:
# variance:  4.732436977583593
# variance:  2.5110809296451233
# variance:  1.45424186784646
# variance:  0.9241658668248729
# variance:  0.8580486765371097
# variance:  0.6452822124678552
# variance:  0.5541414662457824
# variance:  0.35046627494625443
# variance:  0.2905120326939774
# variance:  0.2523200103608244
# variance:  0.2270642817308849
# variance:  0.1697237389801213
# variance:  0.10396199182075308
# 100.00000000000003

# %%
##considering the new X columns
#that is Reduced columns

# %%
X_new = pc.iloc[:,0:3]
X_new
# Out:
#             0         1         2
# 0    3.316751 -1.443463 -0.165739
# 1    2.209465  0.333393 -2.026457
# 2    2.516740 -1.031151  0.982819
# 3    3.757066 -2.756372 -0.176192
# 4    1.008908 -0.869831  2.026688
# ..        ...       ...       ...
# 173 -3.370524 -2.216289 -0.342570
# 174 -2.601956 -1.757229  0.207581
# 175 -2.677839 -2.760899 -0.940942
# 176 -2.387017 -2.297347 -0.550696
# 177 -3.208758 -2.768920  1.013914
#
# [178 rows x 3 columns]

# %%
#Task 3: Clustering with Original Data:
#1.	Apply a clustering algorithm (e.g., K-means) to the original dataset.
#2.	Visualize the clustering results using appropriate plots.
#3.	Evaluate the clustering performance using metrics such as silhouette score or Davies–Bouldin index.

# %%
#==================================================================
# K - means clustering
#==================================================================

import pandas as pd
df = pd.read_csv("wine.csv")
df

from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6,n_init=20)

df["kmeans"] = kmeans.fit_predict(SS_X)
print("Cluster Number with the number of data points")
df["kmeans"].value_counts()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster Number with the number of data points
# kmeans
# 3    53
# 5    48
# 2    28
# 1    24
# 4    18
# 0     7
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

import pandas as pd
df = pd.read_csv("wine.csv")
df

from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4,n_init=20)

df["kmeans"] = kmeans.fit_predict(SS_X)
print("Cluster Numbers with the number of data points")
df["kmeans"].value_counts()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster Numbers with the number of data points
# kmeans
# 1    56
# 0    49
# 2    41
# 3    32
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

import pandas as pd
df = pd.read_csv("wine.csv")
df

from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,n_init=20)

df["kmeans"] = kmeans.fit_predict(SS_X)
print("CLuster Number with the number of data points")
df["kmeans"].value_counts()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# CLuster Number with the number of data points
# kmeans
# 2    65
# 1    62
# 0    51
# Name: count, dtype: int64

# %%
#==================================================================
# K - means clustering
#==================================================================

import pandas as pd
df = pd.read_csv("wine.csv")
df

from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2,n_init=20)

df["kmeans"] = kmeans.fit_predict(SS_X)
df["kmeans"].value_counts()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# kmeans
# 0    113
# 1     65
# Name: count, dtype: int64

# %%
#==============================================================
from sklearn.metrics import silhouette_score

scores = []

for i in range(2,10):
    cluster = KMeans(n_clusters=i,n_init=20)
    df["kmeans"] = cluster.fit_predict(SS_X)
    Y = df["kmeans"]
    scores.append(silhouette_score(SS_X,Y))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
len(scores)
# Out:
# 8

# %%
#printing silhouette scores for individual clusters

# %%
print("order wise silhouette score from k=2 to k=9")

for i in range(0,8):
    print(scores[i])
# Out:
# order wise silhouette score from k=2 to k=9
# 0.25931695553182543
# 0.2848589191898987
# 0.2614352045273167
# 0.22877969615255592
# 0.1999840782311235
# 0.19149127859152779
# 0.13384199539046307
# 0.14880141393471508

# %%
import matplotlib.pyplot as plt
plt.scatter(range(2,10),scores)
plt.plot(range(2,10),scores,color='red')
plt.xlabel("cluster numbers")   
plt.ylabel("silhoutte scores")
plt.show()

# %%
#k=3 has silhoutte score above 0.28 which is the highest

# %%
#let us consider k=3 with dimensions 3 columns.

# %%
#Task 4: Clustering with PCA Data:
#1.	Apply the same clustering algorithm to the PCA-transformed dataset.
#2.	Visualize the clustering results obtained from PCA-transformed data.
#3.	Compare the clustering results from PCA-transformed data with those from the original dataset.

# %%
#considering X and Y variables for model implementation

# %%
X_new
# Out:
#             0         1         2
# 0    3.316751 -1.443463 -0.165739
# 1    2.209465  0.333393 -2.026457
# 2    2.516740 -1.031151  0.982819
# 3    3.757066 -2.756372 -0.176192
# 4    1.008908 -0.869831  2.026688
# ..        ...       ...       ...
# 173 -3.370524 -2.216289 -0.342570
# 174 -2.601956 -1.757229  0.207581
# 175 -2.677839 -2.760899 -0.940942
# 176 -2.387017 -2.297347 -0.550696
# 177 -3.208758 -2.768920  1.013914
#
# [178 rows x 3 columns]

# %%
Y
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      0
#       ..
# 173    1
# 174    1
# 175    5
# 176    5
# 177    1
# Name: kmeans, Length: 178, dtype: int32

# %%
df["Type"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Type, Length: 178, dtype: int64

# %%
Y1=df["Type"]

# %%
Y1
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Type, Length: 178, dtype: int64

# %%
df.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  kmeans
# 0           0.28             2.29   5.64  1.04      3.92     1065       8
# 1           0.26             1.28   4.38  1.05      3.40     1050       8
# 2           0.30             2.81   5.68  1.03      3.17     1185       8
# 3           0.24             2.18   7.80  0.86      3.45     1480       8
# 4           0.39             1.82   4.32  1.04      2.93      735       0

# %%
#implementing CLUSTERING WITH THE TRANSFORMED DATA SET

# %%
#==================================================================
# K - means clustering
#==================================================================


#X = df.iloc[:, 2:]
    
#from sklearn.preprocessing import StandardScaler
#SS = StandardScaler()
#SS_X = SS.fit_transform(X)

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6,n_init=20)

df["kmeans"] = kmeans.fit_predict(X_new)
df["kmeans"].value_counts()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# kmeans
# 3    41
# 5    32
# 2    27
# 1    27
# 4    27
# 0    24
# Name: count, dtype: int64

# %%
#==============================================================
from sklearn.metrics import silhouette_score

scores = []

for i in range(2,10):
    cluster = KMeans(n_clusters=i,n_init=20)
    df["kmeans1"] = cluster.fit_predict(X_new)
    Y = df["kmeans1"]
    scores.append(silhouette_score(X_new,Y))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
len(scores)
# Out:
# 8

# %%
print("SILHOUETTE SCORES FOR PCA TRANFORMED DATA SET")
for i in range(0,8):
    print(scores[i])
# Out:
# SILHOUETTE SCORES FOR PCA TRANFORMED DATA SET
# 0.38938813089003327
# 0.4532351215683952
# 0.4110296819768859
# 0.38526414369551587
# 0.30778398336863594
# 0.308374066166977
# 0.2905276771274141
# 0.3052092523032283

# %%
    
import matplotlib.pyplot as plt
plt.scatter(range(2,10),scores)
plt.plot(range(2,10),scores,color='red')
plt.xlabel("cluster numbers")   
plt.ylabel("silhoutte scores")
plt.show()

# %%
#CONCLUSION AND COMPARISION
#ORIGINAL DATA CLUSTERS AND NUMBER OF DATA POINTS

#3    49
#0    39
#2    29
#5    22
#4    22
#1    17

#K MEANS CLUSTERING WTIH THE TRANSFORMED  DATA SET.
#2    43
#5    32
#3    30
#0    27
#1    24
#4    22

# %%
#we can obsevre good results with the pca tranformed dataset.

# %%
#detailed explaination provided in the documentfile.
